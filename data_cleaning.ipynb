# %%
import pandas as pd
import os
import matplotlib as plt
import numpy as np
import seaborn as sns

# %%
print(os.listdir())
# Out:
# ['.DS_Store', 'Untitled-1.ipynb', 'data_cleaning.ipynb', 'Exercise Files', 'blackjack.ipynb', 'work-and-employment-csv-1.csv', '.ipynb_checkpoints', 'vehicles.csv']

# %%
df = pd.read_csv('work-and-employment-csv-1.csv')

# %%
df.head()
# Out:
#                 Location  \
# 0            Timor-Leste
# 1  Moldova (Republic of)
# 2    Palestine, State of
# 3                  Samoa
# 4                 Jordan
#
#    Employment to population ratio(% ages 15 and older) 2013  \
# 0                                               36.2
# 1                                               38.6
# 2                                               31.6
# 3                                                NaN
# 4                                               36.3
#
#    Labour force participation rate (% ages 15 and older) 2013  \
# 0                                               37.9
# 1                                               40.7
# 2                                               41.2
# 3                                               41.5
# 4                                               41.6
#
#    Employment in agriculture (% of total employment) 1990  \
# 0                                                NaN
# ...

# %%
df.isnull().sum()
# Out:
# Location                                                       16
# Employment to population ratio(% ages 15 and older) 2013       36
# Labour force participation rate (% ages 15 and older) 2013     29
# Employment in agriculture (% of total employment) 1990        151
# Employment in agriculture (% of total employment) 2012         68
# Employment in services (% of total employment) 1990           131
# Employment in services (% of total employment) 2012            68
# Labour force with tertiary education (%) 2007-2012            134
# Vulnerable employment (% of total employment) 2008-2013        81
# Total Unemployment (% of labour force) 2008-2013               45
# Long term Unemployment (% of labour force) 2008-2013          138
# Youth (% of youth labour force) 2008-2014                      54
# Youth not in school or employment (% ages 15Ð24) 2008-2013    140
# Output per worker (2011 PPP $) 2005-2012                       79
# ...

# %% [markdown]
# # Handling the Problem

# %%
missing_value = ['N/A', 'na', np.nan]
df = pd.read_csv('work-and-employment-csv-1.csv', na_values=missing_value)

# %%
df.isnull().sum().sort_values(inplace=True)

# %%
df.drop(df.columns[[10,11,12,13,14]], axis = 1, inplace=True)

# %%
df.head()
# Out:
#                 Location  \
# 0            Timor-Leste
# 1  Moldova (Republic of)
# 2    Palestine, State of
# 3                  Samoa
# 4                 Jordan
#
#    Employment to population ratio(% ages 15 and older) 2013  \
# 0                                               36.2
# 1                                               38.6
# 2                                               31.6
# 3                                                NaN
# 4                                               36.3
#
#    Labour force participation rate (% ages 15 and older) 2013  \
# 0                                               37.9
# 1                                               40.7
# 2                                               41.2
# 3                                               41.5
# 4                                               41.6
#
#    Employment in agriculture (% of total employment) 1990  \
# 0                                                NaN
# ...

# %%
sns.heatmap(df.isnull(), yticklabels=False, xticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Removing NA Values

# %%
df.dropna(how = 'all')
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 202                Grenada
# 203             San Marino
# 204                  Palau
# 205       Marshall Islands
# 206                 Tuvalu
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                 36.2
# 1                                                 38.6
# 2                                                 31.6
# 3                                                  NaN
# 4                                                 36.3
# ..                                                 ...
# 202                                                NaN
# 203                                                NaN
# 204                                                NaN
# 205                                                NaN
# ...

# %%
df.fillna(0)
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                      0
# 219                      0
# 220                      0
# 221                      0
# 222                      0
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                 36.2
# 1                                                 38.6
# 2                                                 31.6
# 3                                                  0.0
# 4                                                 36.3
# ..                                                 ...
# 218                                                0.0
# 219                                                0.0
# 220                                                0.0
# 221                                                0.0
# ...

# %%
df.fillna(method='ffill')
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                 Tuvalu
# 219                 Tuvalu
# 220                 Tuvalu
# 221                 Tuvalu
# 222                 Tuvalu
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                 36.2
# 1                                                 38.6
# 2                                                 31.6
# 3                                                 31.6
# 4                                                 36.3
# ..                                                 ...
# 218                                               86.0
# 219                                               86.0
# 220                                               86.0
# 221                                               86.0
# ...

# %%
df.fillna(method='bfill')
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                    NaN
# 219                    NaN
# 220                    NaN
# 221                    NaN
# 222                    NaN
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                 36.2
# 1                                                 38.6
# 2                                                 31.6
# 3                                                 36.3
# 4                                                 36.3
# ..                                                 ...
# 218                                                NaN
# 219                                                NaN
# 220                                                NaN
# 221                                                NaN
# ...

# %%
df.interpolate()
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                    NaN
# 219                    NaN
# 220                    NaN
# 221                    NaN
# 222                    NaN
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                36.20
# 1                                                38.60
# 2                                                31.60
# 3                                                33.95
# 4                                                36.30
# ..                                                 ...
# 218                                              86.00
# 219                                              86.00
# 220                                              86.00
# 221                                              86.00
# ...

# %%
df_dropped = df.dropna()

# %%
df_dropped
# Out:
#                                               Location  \
# 1                                Moldova (Republic of)
# 15                                               Italy
# 16                                              Turkey
# 19                                             Morocco
# 21                                             Hungary
# 27                                              Greece
# 28                                             Belgium
# 29                                            Bulgaria
# 33                                            Pakistan
# 37                                           Sri Lanka
# 41                                              France
# 45                                             Romania
# 46                                              Poland
# 50                                          Luxembourg
# 53                                           Mauritius
# 55                              Hong Kong, China (SAR)
# ...

# %%
df.fillna(df.median())
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                    NaN
# 219                    NaN
# 220                    NaN
# 221                    NaN
# 222                    NaN
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                 36.2
# 1                                                 38.6
# 2                                                 31.6
# 3                                                 59.1
# 4                                                 36.3
# ..                                                 ...
# 218                                               59.1
# 219                                               59.1
# 220                                               59.1
# 221                                               59.1
# ...

# %%
df.fillna(df.mean())
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                    NaN
# 219                    NaN
# 220                    NaN
# 221                    NaN
# 222                    NaN
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                             36.20000
# 1                                             38.60000
# 2                                             31.60000
# 3                                             58.79893
# 4                                             36.30000
# ..                                                 ...
# 218                                           58.79893
# 219                                           58.79893
# 220                                           58.79893
# 221                                           58.79893
# ...

# %%
df.fillna(50)
# Out:
#                   Location  \
# 0              Timor-Leste
# 1    Moldova (Republic of)
# 2      Palestine, State of
# 3                    Samoa
# 4                   Jordan
# ..                     ...
# 218                     50
# 219                     50
# 220                     50
# 221                     50
# 222                     50
#
#      Employment to population ratio(% ages 15 and older) 2013  \
# 0                                                 36.2
# 1                                                 38.6
# 2                                                 31.6
# 3                                                 50.0
# 4                                                 36.3
# ..                                                 ...
# 218                                               50.0
# 219                                               50.0
# 220                                               50.0
# 221                                               50.0
# ...
